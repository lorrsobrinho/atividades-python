# %% [markdown]
# <a href="https://colab.research.google.com/github/lorrsobrinho/atividades-python/blob/main/C%C3%B3pia_de_Atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade01-Introduçao ao python

# %%
print ("Ola Mundo!")
print ("Curso tecnico em informatica")
# Out:
# Ola Mundo!
# Curso tecnico em informatica

# %%
disciplina = input ("Digite o nome da disciplina:")
conteudo = input ("digite o conteudo estudado:")
atividade = input ("digite o numero da ativdade:")
print ("\n---Informaçoes da atividade---")
print("disciplina:, displina")
print("conteudo:, conteudo")
print("numero da atividade:, atividade")
# Out:
# Digite o nome da disciplina:algoritimo
# digite o conteudo estudado:python
# digite o numero da ativdade:1
#
# ---Informaçoes da atividade---
# disciplina:, displina
# conteudo:, conteudo
# numero da atividade:, atividade
