# %% [markdown]
# <a href="https://colab.research.google.com/github/lorrsobrinho/atividades-python/blob/main/C%C3%B3pia_de_atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividades 01 _ Introdução ao Python

# %%
print("Ola,mundo!")
print ("curso tecnico em informatica")
# Out:
# Ola,mundo!
# curso tecnico em informatica

# %%
disciplina= input("Digite o nome da disciplina:")
conteudo= input("Digite o conteudo estudado")
atividade =input("Digite o numero da atividade")
print("\n---Informações da atividade---")
print("Disciplina:",disciplina)
print("conteudo:",conteudo)
print("atividades:", atividade)
# Out:
# Digite o nome da disciplina:ALP
# Digite o conteudo estudadointrodução ao python
# Digite o numero da atividade01
#
# ---Informações da atividade---
# Disciplina: ALP
# conteudo: introdução ao python
# atividades: 01
